# %%
import pandas as pd
import numpy as np
import datetime
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
customer_df
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  \
# ...

# %%
customer_df.columns = customer_df.columns.str.lower().str.replace(' ', '_')

# %%
 customer_df = customer_df.set_index('customer')

# %%
data_num = customer_df.select_dtypes(np.number)
data_cat = customer_df.select_dtypes(np.object)

# %%
data_num.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
for column in data_num :
    sns.boxplot(data_num[column])
    plt.show()

# %%
for column in data_num:
    upper = np.percentile(data_num[column],75)
    lower = np.percentile(data_num[column],25)
    iqr = upper - lower
    upper_limit = upper + 1.5 * iqr
    lower_limit = lower - 1.5 * iqr
    clean_data_num = data_num[(data_num[column]>lower_limit) & (data_num[column]<upper_limit)]

# %%
for column in clean_data_num :
    sns.boxplot(clean_data_num[column])
    plt.show()

# %%
clean_data_num.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              8681.000000   8681.000000           8681.000000
# mean               7691.288196  38671.169105             89.033061
# std                6376.126782  30320.745669             27.095584
# min                1898.007675      0.000000             61.000000
# 25%                3893.305281  12430.000000             68.000000
# 50%                5635.746396  35205.000000             80.000000
# 75%                8696.710700  63288.000000            106.000000
# max               67907.270500  99981.000000            296.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count              8681.000000                    8681.000000
# mean                 15.034904                      47.966018
# std                  10.072207                      27.855645
# min                   0.000000                       0.000000
# ...

# %%
clean_data_num2 = clean_data_num.copy()

# %%
def funk(clean_data_num2):
    categoricals=customer_df.select_dtypes('object')
    discrete=customer_df.select_dtypes('int64')
    continuous=customer_df.select_dtypes('float64')
    return categoricals, discrete, continuous

# %%
categoricals, discrete, continuous = funk(customer_df)

# %%
from sklearn.preprocessing import MinMaxScaler

transformer = MinMaxScaler().fit(continuous)
x_min_max = transformer.transform(continuous)
x_min_max
# Out:
# array([[0.01062925, 0.13297388],
#        [0.06240565, 0.39105113],
#        [0.13495982, 0.19576416],
#        ...,
#        [0.07695057, 0.27329676],
#        [0.06909758, 0.2388757 ],
#        [0.00876645, 0.12771622]])

# %%
nums_normalized=pd.DataFrame(x_min_max)
nums_normalized
# Out:
#              0         1
# 0     0.010629  0.132974
# 1     0.062406  0.391051
# 2     0.134960  0.195764
# 3     0.070589  0.183117
# 4     0.011245  0.047710
# ...        ...       ...
# 9129  0.264137  0.068485
# 9130  0.014719  0.131034
# 9131  0.076951  0.273297
# 9132  0.069098  0.238876
# 9133  0.008766  0.127716
#
# [9134 rows x 2 columns]

# %%
nums_normalized.columns= [['customer_lifetime_value','customer_claim_amount']]

# %%
categoricals
# Out:
#                state response  coverage education effective_to_date  \
# customer
# BU79786   Washington       No     Basic  Bachelor           2/24/11
# QZ44356      Arizona       No  Extended  Bachelor           1/31/11
# AI49188       Nevada       No   Premium  Bachelor           2/19/11
# WW63253   California       No     Basic  Bachelor           1/20/11
# HB64268   Washington       No     Basic  Bachelor            2/3/11
# ...              ...      ...       ...       ...               ...
# LA72316   California       No     Basic  Bachelor           2/10/11
# PK87824   California      Yes  Extended   College           2/12/11
# TD14365   California       No  Extended  Bachelor            2/6/11
# UP19263   California       No  Extended   College            2/3/11
# Y167826   California       No  Extended   College           2/14/11
#
#          employmentstatus gender location_code marital_status     policy_type  \
# customer
# ...

# %%
categoricals['effective_to_date']= pd.to_datetime(categoricals['effective_to_date'])

# %%
categoricals['year'] = pd.DatetimeIndex(categoricals['effective_to_date']).year
categoricals['month'] = pd.DatetimeIndex(categoricals['effective_to_date']).month
categoricals['day'] = pd.DatetimeIndex(categoricals['effective_to_date']).day
categoricals
# Out:
#                state response  coverage education effective_to_date  \
# customer
# BU79786   Washington       No     Basic  Bachelor        2011-02-24
# QZ44356      Arizona       No  Extended  Bachelor        2011-01-31
# AI49188       Nevada       No   Premium  Bachelor        2011-02-19
# WW63253   California       No     Basic  Bachelor        2011-01-20
# HB64268   Washington       No     Basic  Bachelor        2011-02-03
# ...              ...      ...       ...       ...               ...
# LA72316   California       No     Basic  Bachelor        2011-02-10
# PK87824   California      Yes  Extended   College        2011-02-12
# TD14365   California       No  Extended  Bachelor        2011-02-06
# UP19263   California       No  Extended   College        2011-02-03
# Y167826   California       No  Extended   College        2011-02-14
#
#          employmentstatus gender location_code marital_status     policy_type  \
# customer
# ...

# %%
categoricals_w_d = categoricals.copy()

# %%
categoricals.drop(['effective_to_date','year','month','day'], axis=1, inplace=True)

# %%
categoricals
# Out:
#                state response  coverage education employmentstatus gender  \
# customer
# BU79786   Washington       No     Basic  Bachelor         Employed      F
# QZ44356      Arizona       No  Extended  Bachelor       Unemployed      F
# AI49188       Nevada       No   Premium  Bachelor         Employed      F
# WW63253   California       No     Basic  Bachelor       Unemployed      M
# HB64268   Washington       No     Basic  Bachelor         Employed      M
# ...              ...      ...       ...       ...              ...    ...
# LA72316   California       No     Basic  Bachelor         Employed      M
# PK87824   California      Yes  Extended   College         Employed      F
# TD14365   California       No  Extended  Bachelor       Unemployed      M
# UP19263   California       No  Extended   College         Employed      M
# Y167826   California       No  Extended   College       Unemployed      M
#
# ...

# %%
dumm_categoricals= pd.get_dummies(categoricals)
dumm_categoricals
# Out:
#           state_Arizona  state_California  state_Nevada  state_Oregon  \
# customer
# BU79786               0                 0             0             0
# QZ44356               1                 0             0             0
# AI49188               0                 0             1             0
# WW63253               0                 1             0             0
# HB64268               0                 0             0             0
# ...                 ...               ...           ...           ...
# LA72316               0                 1             0             0
# PK87824               0                 1             0             0
# TD14365               0                 1             0             0
# UP19263               0                 1             0             0
# Y167826               0                 1             0             0
#
#           state_Washington  response_No  response_Yes  coverage_Basic  \
# customer
# ...

# %%
semi=pd.concat([discrete,dumm_categoricals], axis=1)
semi
# Out:
#           income  monthly_premium_auto  months_since_last_claim  \
# customer
# BU79786    56274                    69                       32
# QZ44356        0                    94                       13
# AI49188    48767                   108                       18
# WW63253        0                   106                       18
# HB64268    43836                    73                       12
# ...          ...                   ...                      ...
# LA72316    71941                    73                       18
# PK87824    21604                    79                       14
# TD14365        0                    85                        9
# UP19263    21941                    96                       34
# Y167826        0                    77                        3
#
#           months_since_policy_inception  number_of_open_complaints  \
# customer
# BU79786                               5                          0
# ...

# %%
nums_normalized.reset_index(drop=True).merge(semi.reset_index(drop=True), left_index=True, right_index=True)
# Out:
#       (customer_lifetime_value,)  (customer_claim_amount,)  income  \
# 0                       0.010629                  0.132974   56274
# 1                       0.062406                  0.391051       0
# 2                       0.134960                  0.195764   48767
# 3                       0.070589                  0.183117       0
# 4                       0.011245                  0.047710   43836
# ...                          ...                       ...     ...
# 9129                    0.264137                  0.068485   71941
# 9130                    0.014719                  0.131034   21604
# 9131                    0.076951                  0.273297       0
# 9132                    0.069098                  0.238876   21941
# 9133                    0.008766                  0.127716       0
#
#       monthly_premium_auto  months_since_last_claim  \
# 0                       69                       32
# 1                       94                       13
# ...

# %%
full_table = nums_normalized.reset_index(drop=True).merge(semi.reset_index(drop=False), left_index=True, right_index=True)

# %%
 full_table = full_table.set_index('customer')

# %%
full_table
# Out:
#           (customer_lifetime_value,)  (customer_claim_amount,)  income  \
# customer
# BU79786                     0.010629                  0.132974   56274
# QZ44356                     0.062406                  0.391051       0
# AI49188                     0.134960                  0.195764   48767
# WW63253                     0.070589                  0.183117       0
# HB64268                     0.011245                  0.047710   43836
# ...                              ...                       ...     ...
# LA72316                     0.264137                  0.068485   71941
# PK87824                     0.014719                  0.131034   21604
# TD14365                     0.076951                  0.273297       0
# UP19263                     0.069098                  0.238876   21941
# Y167826                     0.008766                  0.127716       0
#
#           monthly_premium_auto  months_since_last_claim  \
# customer
# ...

# %%
final_full_table = pd.concat([full_table,categoricals_w_d[['year','month','day']]], axis=1)

# %%
final_full_table
# Out:
#           (customer_lifetime_value,)  (customer_claim_amount,)  income  \
# customer
# BU79786                     0.010629                  0.132974   56274
# QZ44356                     0.062406                  0.391051       0
# AI49188                     0.134960                  0.195764   48767
# WW63253                     0.070589                  0.183117       0
# HB64268                     0.011245                  0.047710   43836
# ...                              ...                       ...     ...
# LA72316                     0.264137                  0.068485   71941
# PK87824                     0.014719                  0.131034   21604
# TD14365                     0.076951                  0.273297       0
# UP19263                     0.069098                  0.238876   21941
# Y167826                     0.008766                  0.127716       0
#
#           monthly_premium_auto  months_since_last_claim  \
# customer
# ...
